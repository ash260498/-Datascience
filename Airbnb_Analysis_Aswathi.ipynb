# %% [markdown]
# <a href="https://colab.research.google.com/github/ash260498/EDA-Datascience/blob/main/Airbnb_Analysis_Aswathi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - AIRBNB BOOKING ANALYSIS(EDA)

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Aswathi Rajesh

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This is an exploratory data analysis project on Airbnb analysis. The dataset used is Airbnb NYC 2019 which has 48,895 rows and 16 columns like id which represents the Unique ID, name represents the name of listing, host_id is the unique host ID, host name represents the name of the host.We have to analyze all these information which is present across the dataset like what is the roomtype and price of the rooom. What are the neighbourhood locations etc. These all steps of analysing and modifying the data comes under EDA. Exploratory Data Analysis(EDA)is an approach that is used to analyze the data and discover trends, patterns, or check assumptions in data with the help of statistical summaries and graphical representations. the task is to read and understand the data, handling the missing and null values and explaining the results using some meaningful charts.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/ash260498/EDA-Datascience/blob/main/Airbnb_Analysis_Aswathi.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **The Problem this capstone project aims at analyzing Airbnb's New York City(NYC)data of 2019 which is one of the most famous cities in the world and also the top global destination of tourists.We are visulazing the dataset using Exploratory Data Analysis technique. By analysing this we will find out the distribution of every Airbnb listing based on their location, roomtype, price range and other related factors**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The objectives are
# *   To find the most popular/demanded host of Airbnb in Newyork
# *   To find the average preferred price by customers according to the location and also number of active hosts per location.
# *   To find where customer pays highest and lowest rent according to the location
# *   To find room types and their relation with the availability in different neighourhood groups.
# *   To find top 3 hosts based on their turnover
# *   To find total number of nights spend per location.
# *   To find top 10 hosts with most listings
# *   TO find the highest listing neighbourhood.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 7)
import seaborn as sns
# Mount Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
file_path = '/content/drive/MyDrive/AlmaBetter/EDAProject/Airbnb_NYC_2019.csv'
df=pd.read_csv(file_path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

df.head(5)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
num_rows = df.shape[0]
num_columns=df.shape[1]
print(f"Number of rows: {num_rows}")
print(f"Number of columns:{num_columns}")
# Out:
# Number of rows: 48895
# Number of columns:16

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
#Remove latitude, longitude, last_review and reviews_per_month columns from original dataset
df.drop(df.columns[[6,7,12,13]], axis=1, inplace=True)

# %%
#Removing the Duplicates if any
df.duplicated().sum()
df.drop_duplicates(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48895 entries, 0 to 48894
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   room_type                       48895 non-null  object
#  7   price                           48895 non-null  int64
#  8   minimum_nights                  48895 non-null  int64
#  9   number_of_reviews               48895 non-null  int64
#  10  calculated_host_listings_count  48895 non-null  int64
#  11  availability_365                48895 non-null  int64
# ...

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
null_value_counts = df.isnull().sum()
print(null_value_counts)
# Out:
# id                                 0
# name                              16
# host_id                            0
# host_name                         21
# neighbourhood_group                0
# neighbourhood                      0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# calculated_host_listings_count     0
# availability_365                   0
# dtype: int64

# %%
# Visualizing the missing values
msno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset consists of 48895 observations with various types of field in the dataset
# The fields like id, name,hostid,hostname,neighbourhood group, neighbourhood roomtype,price,minimum nights, number of review, last review, reviews per month, calculated host listing count, availability of rooms also where the null values are present

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
airbnb_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood        room_type  price  \
# 0         John            Brooklyn    Kensington     Private room    149
# 1     Jennifer           Manhattan       Midtown  Entire home/apt    225
# 2    Elisabeth           Manhattan        Harlem     Private room    150
# 3  LisaRoxanne            Brooklyn  Clinton Hill  Entire home/apt     89
# 4        Laura           Manhattan   East Harlem  Entire home/apt     80
#
#    minimum_nights  number_of_reviews  calculated_host_listings_count  \
# ...

# %%
# Dataset Describe
airbnb_df.describe()
# Out:
#                  id       host_id         price  minimum_nights  \
# count  4.885800e+04  4.885800e+04  48858.000000    48858.000000
# mean   1.902335e+07  6.763169e+07    152.740309        7.012444
# std    1.098289e+07  7.862389e+07    240.232386       20.019757
# min    2.539000e+03  2.438000e+03      0.000000        1.000000
# 25%    9.475980e+06  7.818669e+06     69.000000        1.000000
# 50%    1.969114e+07  3.079133e+07    106.000000        3.000000
# 75%    2.915765e+07  1.074344e+08    175.000000        5.000000
# max    3.648724e+07  2.743213e+08  10000.000000     1250.000000
#
#        number_of_reviews  calculated_host_listings_count  availability_365
# count       48858.000000                    48858.000000      48858.000000
# mean           23.273098                        7.148369        112.801425
# std            44.549898                       32.964600        131.610962
# min             0.000000                        1.000000          0.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# This will display the descriptive statistics for categorical variables,including the count, number of unique values, most frequent value, their mininum percentage values, max percentage values allowing us to better understanding the data and its characteristics.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for column in df.columns:
  #Get unique values for the current columns
  unique_values=df[column].unique()
  print(f"Unique values for column'{column}:")
  print(unique_values)
# Out:
# Unique values for column'id:
# [    2539     2595     3647 ... 36485431 36485609 36487245]
# Unique values for column'name:
# ['Clean & quiet apt home by the park' 'Skylit Midtown Castle'
#  'THE VILLAGE OF HARLEM....NEW YORK !' ...
#  'Sunny Studio at Historical Neighborhood'
#  '43rd St. Time Square-cozy single bed'
#  "Trendy duplex in the very heart of Hell's Kitchen"]
# Unique values for column'host_id:
# [     2787      2845      4632 ... 274321313  23492952  68119814]
# Unique values for column'host_name:
# ['John' 'Jennifer' 'Elisabeth' ... 'Abayomi' 'Alberth' 'Ilgar & Aysel']
# Unique values for column'neighbourhood_group:
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# Unique values for column'neighbourhood:
# ['Kensington' 'Midtown' 'Harlem' 'Clinton Hill' 'East Harlem'
#  'Murray Hill' 'Bedford-Stuyvesant' "Hell's Kitchen" 'Upper West Side'
#  'Chinatown' 'South Slope' 'West Village' 'Williamsburg' 'Fort Greene'
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
#Average_price of property according to the location
avg_preffered_price_df = airbnb_df.groupby(['neighbourhood_group','room_type'], as_index=False)['price'].mean().rename(columns={'neighbourhood_group':'Location','price':'Average Price'})
avg_preffered_price_df
# Out:
#          Location        room_type  Average Price
# 0           Bronx  Entire home/apt     127.645503
# 1           Bronx     Private room      66.788344
# 2           Bronx      Shared room      58.610169
# 3        Brooklyn  Entire home/apt     178.362609
# 4        Brooklyn     Private room      76.510619
# 5        Brooklyn      Shared room      50.527845
# 6       Manhattan  Entire home/apt     249.238211
# 7       Manhattan     Private room     116.805594
# 8       Manhattan      Shared room      88.977083
# 9          Queens  Entire home/apt     147.050573
# 10         Queens     Private room      71.776855
# 11         Queens      Shared room      69.020202
# 12  Staten Island  Entire home/apt     173.846591
# 13  Staten Island     Private room      62.292553
# 14  Staten Island      Shared room      57.444444

# %%
#Apply group by operation on neighbourhood_group for find the number of host according to location
no_of_host_per_location = airbnb_df.groupby('neighbourhood_group',as_index=False)['host_id'].count().sort_values(['host_id'], ascending=False).rename(columns={'neighbourhood_group':'Location','host_id':'Host'})
no_of_host_per_location
# Out:
#         Location   Host
# 2      Manhattan  21643
# 1       Brooklyn  20089
# 3         Queens   5664
# 0          Bronx   1089
# 4  Staten Island    373

# %%
#Take a simple format of above question without index for plot the line chart
no_of_host_per_location = airbnb_df.groupby('neighbourhood_group')['host_id'].count()
no_of_host_per_location
# Out:
# neighbourhood_group
# Bronx             1089
# Brooklyn         20089
# Manhattan        21643
# Queens            5664
# Staten Island      373
# Name: host_id, dtype: int64

# %%
#identify the observations where minimum nights is 1 and price is minimum
airbnb_df[airbnb_df['minimum_nights'] ==1].sort_values(['price', 'minimum_nights'], ascending=[True, True])
# Out:
#              id                                               name    host_id  \
# 25794  20639628  Spacious comfortable master bedroom with nice ...   86327101
# 25795  20639792  Contemporary bedroom in brownstone with nice view   86327101
# 25796  20639914       Cozy yet spacious private brownstone bedroom   86327101
# 21700  17437106               Couch in Harlem Harvey Refugees only   33511962
# 22835  18490141                            IT'S SIMPLY CONVENIENT!   97001292
# ...         ...                                                ...        ...
# 44034  33998396                   3000 sq ft daylight photo studio    3750764
# 42523  33007610                70' Luxury MotorYacht on the Hudson    7407743
# 45666  34895693                               Gem of east Flatbush  262534951
# 29662  22779726          East 72nd Townhouse by (Hidden by Airbnb)  156158778
# 4377    2953058                                      Film Location    1177497
#
# ...

# %%
#Get the number of values which price is less than 100$
airbnb_df.loc[airbnb_df['price'] < 100,'price'].count()
# Out:
# 21861

# %%
#Make a copy of original dataframe to perform additional operation for get the desire result
airbnb_price_df = airbnb_df.copy()

# %%
#Find the mean value of price which value is less than 100$
round(airbnb_df.loc[airbnb_df['price'] < 100,'price'].mean())
# Out:
# 65

# %%
#Change the value of price where minimum night = 1 and price of their property is less than 50$
airbnb_price_df['price'] = np.where(
   (airbnb_price_df['price'] <= 50) & (airbnb_price_df['minimum_nights'] == 1) ,round(airbnb_df.loc[airbnb_df['price'] < 100,'price'].mean()) , airbnb_price_df['price']
   )

# %%
#still 8 rows have amount = 0$
airbnb_price_df[airbnb_price_df['price']==0].count()
# Out:
# id                                8
# name                              8
# host_id                           8
# host_name                         8
# neighbourhood_group               8
# neighbourhood                     8
# room_type                         8
# price                             8
# minimum_nights                    8
# number_of_reviews                 8
# calculated_host_listings_count    8
# availability_365                  8
# dtype: int64

# %%
#Find the observations where price is 0$
airbnb_price_df[airbnb_price_df['price']==0]
# Out:
#              id                                               name    host_id  \
# 23161  18750597  Huge Brooklyn Brownstone Living, Close to it all.    8993084
# 25433  20333471      ★Hostel Style Room | Ideal Traveling Buddies★  131697576
# 25634  20523843    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)   15787004
# 25753  20608117                    Sunny, Quiet Room in Greenpoint    1641537
# 25778  20624541      Modern apartment in the heart of Williamsburg   10132166
# 26259  20933849                              the best you can find   13709292
# 26841  21291569  Coliving in Brooklyn! Modern design / Shared room  101970559
# 26866  21304320             Best Coliving space ever! Shared room.  101970559
#
#           host_name neighbourhood_group       neighbourhood        room_type  \
# 23161      Kimberly            Brooklyn  Bedford-Stuyvesant     Private room
# 25433        Anisha               Bronx     East Morrisania     Private room
# ...

# %%
#Function that gives a new price according to minimum night
def price_calculator(min_night):
  '''Get the price based on the minimum night you are given'''
  mean_price = round(airbnb_df.loc[airbnb_df['price'] < 100,'price'].mean())
  new_price = mean_price * min_night

  return new_price

# %%
#Replace the value of price according to minimum night where price = 0$
airbnb_price_df['price'] = np.where(
   (airbnb_price_df['price'] == 0) ,price_calculator(airbnb_price_df['minimum_nights']) , airbnb_price_df['price'])

# %%
#Our new description of dataset
airbnb_price_df.describe()
# Out:
#                  id       host_id         price  minimum_nights  \
# count  4.885800e+04  4.885800e+04  48858.000000    48858.000000
# mean   1.902335e+07  6.763169e+07    153.846801        7.012444
# std    1.098289e+07  7.862389e+07    240.078850       20.019757
# min    2.539000e+03  2.438000e+03     10.000000        1.000000
# 25%    9.475980e+06  7.818669e+06     69.000000        1.000000
# 50%    1.969114e+07  3.079133e+07    106.000000        3.000000
# 75%    2.915765e+07  1.074344e+08    175.000000        5.000000
# max    3.648724e+07  2.743213e+08  10000.000000     1250.000000
#
#        number_of_reviews  calculated_host_listings_count  availability_365
# count       48858.000000                    48858.000000      48858.000000
# mean           23.273098                        7.148369        112.801425
# std            44.549898                       32.964600        131.610962
# min             0.000000                        1.000000          0.000000
# ...

# %%
#Get the highest rent according to location
max_price_df = airbnb_price_df.groupby('neighbourhood_group',as_index=False)['price'].max().sort_values(['price'],ascending = False).rename(columns = {'price':'Maximum price','neighbourhood_group':'Location'})
max_price_df
# Out:
#         Location  Maximum price
# 1       Brooklyn          10000
# 2      Manhattan          10000
# 3         Queens          10000
# 4  Staten Island           5000
# 0          Bronx           2500

# %%
#Get the lowest rent according to location
min_price_df = airbnb_price_df.groupby('neighbourhood_group',as_index=False)['price'].min().sort_values(['price'],ascending = True).rename(columns = {'price':'Minimum price','neighbourhood_group':'Location'})
min_price_df
# Out:
#         Location  Minimum price
# 1       Brooklyn             10
# 2      Manhattan             10
# 3         Queens             10
# 0          Bronx             20
# 4  Staten Island             20

# %%
#Get the combine dataframe of minimum and maximum price according to location
merge_price_df = pd.merge(max_price_df, min_price_df, on='Location')
merge_price_df
# Out:
#         Location  Maximum price  Minimum price
# 0       Brooklyn          10000             10
# 1      Manhattan          10000             10
# 2         Queens          10000             10
# 3  Staten Island           5000             20
# 4          Bronx           2500             20

# %%
#Create a copy of merge price dataframe
merge_price_df_copy = merge_price_df.copy()

# %%
#Create a function for log transformation of maximum price and minimum price
def log_values(values):
  '''This function takes a price value as a input and give it's log values'''
  new_max_price = np.log2(values)

  return new_max_price

# %%
#Apply above function on merge price dataframe
merge_price_df_copy['Maximum price'] = merge_price_df_copy.apply(lambda x: log_values(x['Maximum price']), axis=1)
merge_price_df_copy['Minimum price'] = merge_price_df_copy.apply(lambda x: log_values(x['Minimum price']), axis=1)

# %%
#Output of maximum price and minimum price after log transformation
merge_price_df_copy
# Out:
#         Location  Maximum price  Minimum price
# 0       Brooklyn      13.287712       3.321928
# 1      Manhattan      13.287712       3.321928
# 2         Queens      13.287712       3.321928
# 3  Staten Island      12.287712       4.321928
# 4          Bronx      11.287712       4.321928

# %%
#Get the host based on number of reviews
host_based_on_review_df = airbnb_price_df.groupby(['host_id','host_name'],as_index=False)['number_of_reviews'].sum().sort_values(['number_of_reviews'],ascending = False)
host_based_on_review_df
# Out:
#          host_id                       host_name  number_of_reviews
# 21294   37312959                            Maya               2273
# 1052      344035  Brooklyn&   Breakfast    -Len-               2205
# 18619   26432133                        Danielle               2017
# 20863   35524316                    Yasu & Akiko               1971
# 21911   40176101                           Brady               1818
# ...          ...                             ...                ...
# 21799   39706334                            Erin                  0
# 21802   39724060                           Jaime                  0
# 21806   39731713                          Polina                  0
# 21812   39765154                            Dave                  0
# 37424  274321313                             Kat                  0
#
# [37425 rows x 3 columns]

# %%
#Get the host based on availability in a year
host_based_on_availability_df = airbnb_price_df.groupby(['host_id','host_name'],as_index=False)['availability_365'].mean().sort_values(['availability_365'],ascending = True)
host_based_on_availability_df
# Out:
#          host_id host_name  availability_365
# 0           2438     Tasos               0.0
# 22244   41764756       Luz               0.0
# 22243   41762539     Maria               0.0
# 22242   41760536    Austin               0.0
# 22241   41757762      Sara               0.0
# ...          ...       ...               ...
# 1787      746552       Tom             365.0
# 27208   76862848    Alexis             365.0
# 22042   40733012    Victor             365.0
# 1829      772862     Jesse             365.0
# 30118  121429669  Elizanda             365.0
#
# [37425 rows x 3 columns]

# %%
#Merge two dataframe based on number of reviews and availability in a year
popular_host_df = pd.merge(host_based_on_review_df,host_based_on_availability_df,on = ['host_id','host_name']).sort_values(['availability_365','number_of_reviews'],ascending = [True,False]).rename(columns = {'number_of_reviews':'Number of reviews','availability_365':'Availability in a year'})
popular_host_df
# Out:
#          host_id        host_name  Number of reviews  Availability in a year
# 12      22959695  Gurpreet  Singh               1157                     0.0
# 41      99392252          Michael                732                     0.0
# 47     121391142          Deloris                693                     0.0
# 122       792159            Wanda                480                     0.0
# 125     37818581            Sofia                479                     0.0
# ...          ...              ...                ...                     ...
# 37133   37360127              Mel                  0                   365.0
# 37137   37424221           Trevor                  0                   365.0
# 37225   35741633             Chen                  0                   365.0
# 37248   40834217              Jay                  0                   365.0
# 37263   40733012           Victor                  0                   365.0
#
# [37425 rows x 4 columns]

# %%
#Most popular top 5 host in new york
popular_host_df.head(5)
# Out:
#        host_id        host_name  Number of reviews  Availability in a year
# 12    22959695  Gurpreet  Singh               1157                     0.0
# 41    99392252          Michael                732                     0.0
# 47   121391142          Deloris                693                     0.0
# 122     792159            Wanda                480                     0.0
# 125   37818581            Sofia                479                     0.0

# %%
# Finding unique values from column 'room_type'
airbnb_room_type = airbnb_df.room_type.unique()

# %%
airbnb_room_type
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
# Which is the most listed room type?
airbnb_roomtype_frequency = dict(airbnb_df.room_type.value_counts())

# %%
airbnb_roomtype_frequency
# Out:
# {'Entire home/apt': 25393, 'Private room': 22306, 'Shared room': 1159}

# %%
#Creating empty list to store name strings
airbnb_names=[]

#Getting name string from 'name' column and appending it to the empty list
for name in airbnb_df.name:
    airbnb_names.append(name)

#Setting a function to split name strings into seperate words
def split_name(name):
    ns = str(name).split()
    return ns

#Creating empty list to store the count of words
names_count = []

#Getting name string to append it to the names_count list
for n in airbnb_names:
    for word in split_name(n):
        word = word.lower()
        names_count.append(word)

# %%
# Importing 'counter' library to count and generate raw data and count top 25 most used words
from collections import Counter

# Counting most common words
count_words = Counter(names_count).most_common()
count_words[:25]
# Out:
# [('in', 16723),
#  ('room', 9383),
#  ('bedroom', 7226),
#  ('private', 6983),
#  ('apartment', 6112),
#  ('cozy', 4631),
#  ('the', 3866),
#  ('to', 3826),
#  ('studio', 3770),
#  ('brooklyn', 3629),
#  ('apt', 3571),
#  ('spacious', 3383),
#  ('1', 3355),
#  ('with', 3092),
#  ('2', 3078),
#  ('of', 2992),
#  ('east', 2966),
#  ('and', 2868),
#  ('manhattan', 2854),
#  ('&', 2820),
#  ('park', 2631),
#  ('sunny', 2535),
#  ('beautiful', 2319),
#  ('near', 2293),
#  ('williamsburg', 2292)]

# %%
# Cleaning the List by removing prepositions
items_to_remove = {('in', 16733), ('the', 3869), ('to', 3827), ('of', 2993), ('-', 2272), ('a', 1909)}
top_25_cleaned = [e for e in count_words if e not in items_to_remove]
top_25 = top_25_cleaned[:25]
top_25
# Out:
# [('in', 16723),
#  ('room', 9383),
#  ('bedroom', 7226),
#  ('private', 6983),
#  ('apartment', 6112),
#  ('cozy', 4631),
#  ('the', 3866),
#  ('to', 3826),
#  ('studio', 3770),
#  ('brooklyn', 3629),
#  ('apt', 3571),
#  ('spacious', 3383),
#  ('1', 3355),
#  ('with', 3092),
#  ('2', 3078),
#  ('of', 2992),
#  ('east', 2966),
#  ('and', 2868),
#  ('manhattan', 2854),
#  ('&', 2820),
#  ('park', 2631),
#  ('sunny', 2535),
#  ('beautiful', 2319),
#  ('near', 2293),
#  ('williamsburg', 2292)]

# %%
#converting the data into DataFrame
word_count_df = pd.DataFrame(top_25)
word_count_df.rename(columns={0:'Words',1:'Counts'},inplace=True)
word_count_df
# Out:
#            Words  Counts
# 0             in   16723
# 1           room    9383
# 2        bedroom    7226
# 3        private    6983
# 4      apartment    6112
# 5           cozy    4631
# 6            the    3866
# 7             to    3826
# 8         studio    3770
# 9       brooklyn    3629
# 10           apt    3571
# 11      spacious    3383
# 12             1    3355
# 13          with    3092
# 14             2    3078
# 15            of    2992
# 16          east    2966
# 17           and    2868
# 18     manhattan    2854
# 19             &    2820
# 20          park    2631
# 21         sunny    2535
# 22     beautiful    2319
# 23          near    2293
# 24  williamsburg    2292

# %%
airbnb_df['host_id'].count()
# Out:
# 48858

# %%
#Creating DataFrame
count_host_id = list(airbnb_df['host_id'].value_counts())
host_id = list(airbnb_df.host_id)
listing_count= list(zip(host_id,count_host_id))
count_host_id_df= pd.DataFrame(listing_count)
count_host_id_df.rename(columns={0:'Host_Id',1:'Counts'},inplace=True)

#Storing top 10 hosts with most listings
top_host_id = count_host_id_df.head(10)
top_host_id
# Out:
#    Host_Id  Counts
# 0     2787     327
# 1     2845     232
# 2     4632     121
# 3     4869     103
# 4     7192      96
# 5     7322      96
# 6     7356      91
# 7     8967      87
# 8     7490      65
# 9     7549      52

# %%
# drop null value from the dataset
non_null_file = df.dropna()
non_null_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48858 entries, 0 to 48894
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48858 non-null  int64
#  1   name                            48858 non-null  object
#  2   host_id                         48858 non-null  int64
#  3   host_name                       48858 non-null  object
#  4   neighbourhood_group             48858 non-null  object
#  5   neighbourhood                   48858 non-null  object
#  6   room_type                       48858 non-null  object
#  7   price                           48858 non-null  int64
#  8   minimum_nights                  48858 non-null  int64
#  9   number_of_reviews               48858 non-null  int64
#  10  calculated_host_listings_count  48858 non-null  int64
#  11  availability_365                48858 non-null  int64
# ...

# %%
# copy of the non_null_file
new=non_null_file.copy()
new.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood        room_type  price  \
# 0         John            Brooklyn    Kensington     Private room    149
# 1     Jennifer           Manhattan       Midtown  Entire home/apt    225
# 2    Elisabeth           Manhattan        Harlem     Private room    150
# 3  LisaRoxanne            Brooklyn  Clinton Hill  Entire home/apt     89
# 4        Laura           Manhattan   East Harlem  Entire home/apt     80
#
#    minimum_nights  number_of_reviews  calculated_host_listings_count  \
# ...

# %%
new['price'].describe()
# Out:
# count    48858.000000
# mean       152.740309
# std        240.232386
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
# replace whose price less than 50
new.loc[new['price']<50,'price'] = new.loc[(new['price']>50) & (new['price']<80),'price'].median()
new['price'].describe()
# Out:
# count    48858.000000
# mean       155.369008
# std        239.104348
# min         50.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
# after removing price less than 100
new.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood        room_type  price  \
# 0         John            Brooklyn    Kensington     Private room    149
# 1     Jennifer           Manhattan       Midtown  Entire home/apt    225
# 2    Elisabeth           Manhattan        Harlem     Private room    150
# 3  LisaRoxanne            Brooklyn  Clinton Hill  Entire home/apt     89
# 4        Laura           Manhattan   East Harlem  Entire home/apt     80
#
#    minimum_nights  number_of_reviews  calculated_host_listings_count  \
# ...

# %%
#  find the maximum price across different host name
top_host=new.groupby(['host_name','host_id'])['price'].sum().reset_index()
top_host.rename(columns={'price':'total_price'},inplace=True)
top_host.head()
#top_host.info()
# Out:
#                   host_name   host_id  total_price
# 0                      'Cil  45354224          120
# 1           (Ari) HENRY LEE  40605120          140
# 2  (Email hidden by Airbnb)   5610823          261
# 3  (Email hidden by Airbnb)   7580102          389
# 4  (Email hidden by Airbnb)  11495251          200

# %%
# find top three host best on their turnover
top_3=top_host.sort_values('total_price',ascending=False).iloc[:3,:3]
top_3
# Out:
#           host_name    host_id  total_price
# 33209  Sonder (NYC)  219517861        82795
# 4856     Blueground  107434423        70331
# 31216         Sally  156158778        37097

# %%
#  find the maximum(minimum nights) spending by customer across different neighourhood group
total_nights=new.groupby('neighbourhood_group')['minimum_nights'].sum().reset_index()
final_nights=total_nights.sort_values('minimum_nights',ascending=True)
final_nights.head()
# Out:
#   neighbourhood_group  minimum_nights
# 4       Staten Island            1802
# 0               Bronx            4971
# 3              Queens           29356
# 1            Brooklyn          121693
# 2           Manhattan          184792

# %%
# find unique value of room types
list(new['room_type'].unique())
# Out:
# ['Private room', 'Entire home/apt', 'Shared room']

# %%
#  find the maximum(minimum nights) spending by customer across different room type
total_room=new.groupby(  'room_type')['minimum_nights'].sum().reset_index()
room_types=total_room.sort_values('minimum_nights',ascending=True)
room_types.head()
# Out:
#          room_type  minimum_nights
# 2      Shared room            7510
# 1     Private room          120023
# 0  Entire home/apt          215081

# %%
# find listing value of all neighourhood in dataset
neighour=new['neighbourhood'].value_counts().sort_values(ascending=False).reset_index()
#top ten neighourhood with listing value
top_10=neighour[:10]
top_10

#m.rename(columns={'index': 'newName1', 'neighourhood': 'newName2'}, inplace=True)
# Out:
#                 index  neighbourhood
# 0        Williamsburg           3917
# 1  Bedford-Stuyvesant           3713
# 2              Harlem           2655
# 3            Bushwick           2462
# 4     Upper West Side           1969
# 5      Hell's Kitchen           1954
# 6        East Village           1852
# 7     Upper East Side           1797
# 8       Crown Heights           1563
# 9             Midtown           1545

# %%
#make copy of top_10
final_10=top_10.copy()
#rename that dataframe
final_10.rename(columns={'index':'neighourhood','neighbourhood':'listing_value' },inplace=True)

final_10
# Out:
#          neighourhood  listing_value
# 0        Williamsburg           3917
# 1  Bedford-Stuyvesant           3713
# 2              Harlem           2655
# 3            Bushwick           2462
# 4     Upper West Side           1969
# 5      Hell's Kitchen           1954
# 6        East Village           1852
# 7     Upper East Side           1797
# 8       Crown Heights           1563
# 9             Midtown           1545

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# We are predicting the average preferred price of the dataframe using groupby operation. Also we have applied groupby operation on the neighbourhood_group to find the number of host according to the location.Also identifying the observations where minimum night is 1 and the price is maximum using sort operation. Here we can see that there is a minimum price 0. We have to fix this because Airbnb will not provide free stay in hotel.So we have used a function where price is 0,will be changed according to the minimum nights spent using the mean valueThere are some entries in which minimum night is 1 but its respective price is 0,For that we have replaced the price value with the mean value of price which amount is less than 100$.Finding the highest and lowest rent according to the location.We have merged two dataframes based on number of reviews and availability in a year. We have also created an empty list to store name strings and setting a function to split name strings into separate words. We have used counter library to count and generate raw data and we have removed prepositions for cleaning the list.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
#Unstack the group by information for plot the graph
avg_preffered_price_df = airbnb_df.groupby(['neighbourhood_group','room_type'])['price'].mean().unstack()
avg_preffered_price_df

#Graph of average price of property according to location
avg_preffered_price_df.plot.bar()
# Out:
# <Axes: xlabel='neighbourhood_group'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are effective for comparing the values or frequencies of different categories.They allow us to quickly visualize and compare the magnitudes or proportions of categories.And also it can convey relationships between different categories and making it easier to interpret and communicate insights quickly. They present data in a straight forward and intuitive manner, making them accessible to wide range of audiences.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# According to the dataset provided , We have analyzed and figured that the Manhattan is having the highest price for home/apt compared to other location.
# Queens, Staten island and Bronx share almost same price for shared and private room, approximately(55$) and the average rice for shared room is lowest in Brooklyn.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# They offer insights into distribution, popularity and trends of different room types within specific areas, helping property owners and hosts make informed decisions about their listings.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
#Graph
plt.legend(labels = ['No. of Host'])
plt.plot(no_of_host_per_location)
plt.title('Number Of Host Per Location')
plt.ylabel('Host')
plt.xlabel('Location')
# Out:
# Text(0.5, 0, 'Location')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line charts are commonly used in python for visualiing trends and patterns in data over time or any continuous variable.They are particularly effective in showing how a variable changes over time. They allow you to observe trends, patterns and fluctuations in data across different time periods, making them ideal for analyzing temporal data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# According to the chart Manhattan and Booklyn are the most preferred locations where the hosts are interested to own the property. And Bronx and staten island is of low traffic whereas Queens is having an average number

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These insights can guide hosts, investors and stakeholders in understanding the dynamics of Airbnb market and make decisions related to hosting, investment opportunities and market positioning.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
#Bar graph for display maximum price and minimum price according to location
merge_price_df_copy.plot(x="Location", y=['Maximum price','Minimum price'], kind="bar")
plt.legend(labels = ['Maximum price','Minimum price'])
plt.title('Maximum and minimum price according to location')
# Out:
# Text(0.5, 1.0, 'Maximum and minimum price according to location')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts can convey relationships between different categories. For example stacked or grouped bar charts can be used to display subcategories within each main category, allowing for the exploration of complex relationships.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we have used log transformation to display maximum price with minimum price.The maximum and minimum rent is almost same in Brooklyn, Manhattan and Queens.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It provides valuable insights into price ranges, premium and budget friendly areas, price variabilty and informs pricing strategies. It helps both hosts and guests understand the market dynamics and make informed decisions relatec to accomodation choices and pricing.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
#Create scatter plot based on number of reviews and availability in a year
popular_host_df.plot.scatter(x='Number of reviews', y='Availability in a year', xlim=(100,1000),ylim=(10,380));

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatter plots are commonly used in Pytho for visualizing the relationship between two continuous variables.They are particularly useful for analyzing the correlation, distribution, and clustering of data points. Scatter plots canbe useful for detecting outliers, which are data points that significantly deviate from the overall pattern.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We have used scatter plot for displaying the most demanded host with respect to number reviews and availabilty in a year.The top 5 hosts of Airbnb in New York city is found using the following code popular_host_df.head(5)

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It allows us to visulaize the host's performance metrics on two axes, such as the number of listings.This visual representation helps you observe the distribution of hosts and identify patterns or outliers in their performance.By plotting the scatter plot, You can quickly identify hosts who excel in terms of both the number of listings and their average rating.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# Creating Dataset

room_type = list(airbnb_roomtype_frequency.keys())
data = list(airbnb_roomtype_frequency.values())

# Creating color parameters

colors = ( "skyblue", "red", "yellow",)

# Creating explode data

explode = (0.03, 0.03, 0.1)

# Wedge properties
wp = { 'linewidth' : 1, 'edgecolor' : "pink" }

# Creating autocpt arguments
def func(pct, allvalues):
    absolute = int(pct / 100.*np.sum(allvalues))
    return "{:.1f}%\n({:d})".format(pct, absolute)

# Creating Pie Chart

# Creating plot
fig, airbnb_pie_chart = plt.subplots(figsize =(12, 8))
wedges, texts, autotexts = airbnb_pie_chart.pie(data, autopct = lambda pct: func(pct, data),
                                                explode = explode,
                                                shadow = True,
                                                colors = colors,
                                                startangle = 0,
                                                wedgeprops = wp,
                                                textprops = dict(color ="black"))

# Adding legend
airbnb_pie_chart.legend(wedges, room_type,
                        title ="Room Type",
                        loc ="upper left",
                        bbox_to_anchor=(1, 0., 0.,1))

plt.setp(autotexts, size = 15, weight = "bold")
airbnb_pie_chart.set_title("Count of Listed Rooms")
# Out:
# Text(0.5, 1.0, 'Count of Listed Rooms')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts are effective for displaying the relative proportions or percentages of different categories in a dataset. It is straightforward and intuitive way to represent data. It is suitable for providing a holistic view of the entire dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# According to the pie chart plotted as per the data, We have found the entire home/apartment is in the highest number of listing and shared room is in the lowest number of listing. Private room has 45.7% of listing among the other room types.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Pie charts effectively illustrate the proportion of the highest number of listings relative to the total. By representing the highest number of listings as a single slice, You can easily compare its size to the rest of the chart,providing a visual understanding of its significance.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
import plotly.offline as pyo
import plotly.graph_objs as go

#Setting up the color pallete
color_dict = {'Private room': '#cc5a49', 'Entire home/apt' : '#4586ac', 'Shared room' : '#C0C0C0'}

#Grouping the room type using 'neighbourhood_group' as an index
airbnb_types=airbnb_df.groupby(['neighbourhood_group', 'room_type']).size()

#Creating function to plot room type proportion on all region area
for region in airbnb_df.neighbourhood_group.unique():

    plt.figure(figsize=(24,12))

    airbnb_reg=airbnb_types[region]
    labels = airbnb_reg.index
    sizes = airbnb_reg.values


    plot_num = 321
    plt.subplot(plot_num)
    reg_ch = go.Figure(data = [go.Pie(labels = labels, values = sizes, hole = 0.6)])
    reg_ch.update_traces(title = region, textfont_size=15, titlefont_size=25)
    reg_ch.update_layout(legend=dict(
    yanchor="top",
    y=0.99,
    xanchor="left",
    x=0.10,
    ))
    reg_ch.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Subplot allow you to compare and contrast the sharing of different roomtypes side by side. By placing subplots side by side, you can visually access the distribution of room sharing across different categories such as private room,shared rooms and entire home or apartments.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In Brooklyn, Private room constitutes 50.4%, Entire home/ apartment constitutes around 47.6% and shared room constitutes around 2.06%.whereas in Manhattan entire home/apartment preferences are moreby the guests than in Brooklyn around 60.9%.In Queens private room has more contribution than shared rooms and apartments. Staten island has same preference by hosts in  both private room and apartments. In Bronx shared room percentage has increased compared to all other places.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We can create separate subplots to display the distribution of roomsharing room type, while also incorporating additional information such as price, ratings, location.This allows for a more comprehensive analyis and exploration of relationships between different variables. And also helps in efficient use of space.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
plt.figure(figsize=(10,10))
sns.set_style('white')

ax = sns.boxplot(data=airbnb_df, x='neighbourhood_group',y='availability_365',palette='plasma')

# Naming the Chart
ax.set_title('Relation between Neighbourhood group & Availability of rooms').set_fontsize('15')

# Naming X & Y axis
ax.set_ylabel('Availability 365 Days').set_fontsize('15')
ax.set_xlabel('Neighbourhood Group').set_fontsize('15')

#Adjusting Bar labels
ax.set_xticklabels(ax.get_xticklabels(), size = '15')
# Out:
# [Text(0, 0, 'Brooklyn'),
#  Text(1, 0, 'Manhattan'),
#  Text(2, 0, 'Queens'),
#  Text(3, 0, 'Staten Island'),
#  Text(4, 0, 'Bronx')]

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Box plots provide a concise way to visualize the distribution of a variable across different categories or groups. In this case, the neighbourhood group serves as the grouping variable, and the availabilty of rooms is the variable of interest.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Outliers are extreme values that fall outside typical range of values.In the context of Airbnb Analysis, outliers could represent exceptional cases where room availabilty is significantly higher or lower than the norm.From this analysis we can say that the people prefer to stay in private rooms in Brooklyn and Mahattan for longer duration of time.Therefore Brooklyn and Manhattan have the least availabilty.Staten island and Bronx has the highest availabilty overall for 300 days.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# They provide a clear and concize visualisation of the distribution, summary statistics. By this you can easily compare the room availablity across neighbourhood groups.This allows to identify any differences or similarities in the distribution of room availability and gain insights into a potential relationship between neighbourhood group and availability of rooms.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
#Setting the figure size
sns.set(rc={'figure.figsize':(12,6)})

#Setting background colour of chart as white
sns.set_style('white')

#Plotting the Chart
count_viz = sns.barplot(x='Words',y='Counts', data = word_count_df)

# Naming the Chart
count_viz.set_title('Top 25 Used Words for Listing Names', weight = 'bold').set_fontsize('15')


# Naming X & Y axis
count_viz.set_ylabel('Count of words', weight = 'bold')
count_viz.set_xlabel('Words', weight = 'bold')

#Adjusting Bar labels
count_viz.set_xticklabels(count_viz.get_xticklabels(),rotation = 90, weight = 'bold', size = '15')
# Out:
# [Text(0, 0, 'in'),
#  Text(1, 0, 'room'),
#  Text(2, 0, 'bedroom'),
#  Text(3, 0, 'private'),
#  Text(4, 0, 'apartment'),
#  Text(5, 0, 'cozy'),
#  Text(6, 0, 'the'),
#  Text(7, 0, 'to'),
#  Text(8, 0, 'studio'),
#  Text(9, 0, 'brooklyn'),
#  Text(10, 0, 'apt'),
#  Text(11, 0, 'spacious'),
#  Text(12, 0, '1'),
#  Text(13, 0, 'with'),
#  Text(14, 0, '2'),
#  Text(15, 0, 'of'),
#  Text(16, 0, 'east'),
#  Text(17, 0, 'and'),
#  Text(18, 0, 'manhattan'),
#  Text(19, 0, '&'),
#  Text(20, 0, 'park'),
#  Text(21, 0, 'sunny'),
#  Text(22, 0, 'beautiful'),
#  Text(23, 0, 'near'),
#  Text(24, 0, 'williamsburg')]

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar plots provide a clear visualization of the frequency of each word in the top 25 list. The height or length of each bar represents the frequency or count of a particular word.The words are typically arranged along X axis and their frequencies are displayed on the Y axis

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The top 5 words in the listing as in,room, bedroom,private, apartment and cozy which are mostly related to property type

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Analyzing the top 25 words used in listing names can provide valuable insights into how hosts describe their listings. It can reveal common themes, keywords or descriptive terms that are frequently used,which may influence potential guest decisions.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
#Importing WordCloud library
from wordcloud import WordCloud, ImageColorGenerator
text = ' '.join(str(n) for n in word_count_df.Words)

#Generating wordcloud image
wordcloud = WordCloud(max_font_size=80, colormap='hsv', width=400, height=150).generate(text)
plt.figure(figsize=(12,8))

#Displaying the image
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Word clouds provide an immediate visual representation of the frequency of words.The sie of each word in the cloud corresponds to its frequency or occurance in the dataset.More frequently used words appear larger, making it easy to identify the most common words at a glance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Word clouds can reveal patterns and insights within the textual data. The arrangement and proximity of the words in the cloud suggest associations or relationships between them. For example, if words like "spacious", "cozy" appear together, it may indicate common attributes or features emphasized by hosts

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# They can be easily understood and interpreted by both technical and non technical stake holders. The visual impact of the word cloud can effectively convey the main themes and keywords used in the listings.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
#Setting the figure size
sns.set(rc={'figure.figsize':(10,8)})

#Setting background colour of chart as white
sns.set_style('white')

#Plotting the Chart
viz_bar = sns.barplot(x= 'Host_Id', y= 'Counts', color='g', data=top_host_id,
                      order=top_host_id.sort_values('Counts',ascending = False).Host_Id)

#Setting font size for title
sns.set(font_scale = 2)

# Naming the Chart
viz_bar.set_title('Hosts with most listings in New York')

# Naming X & Y axis
viz_bar.set_xlabel('Host IDs')
viz_bar.set_ylabel('Count of listings')

#Adjusting Bar labels
viz_bar.set_xticklabels(viz_bar.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, '2787'),
#  Text(1, 0, '2845'),
#  Text(2, 0, '4632'),
#  Text(3, 0, '4869'),
#  Text(4, 0, '7192'),
#  Text(5, 0, '7322'),
#  Text(6, 0, '7356'),
#  Text(7, 0, '8967'),
#  Text(8, 0, '7490'),
#  Text(9, 0, '7549')]

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts allow for easy comparison,identification of top hosts, understanding the distribution of listings,assessing market concentration.It provides a clear overview of the distribution of listings among different hosts in New York

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Bar Charts can help assess the concentration of listings among hosts in New York. If there are only a few hosts with a substantial number of listings, it suggests a higher level of market concentration. We can observe trends in the number of listings for different hosts in New York.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These visualizations provide valuable insights into the competitive landscape and market dynamics of Airbnb in New York.This information can be useful for other hosts looking to optimie their listing strategies or learn from successful market participants.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
sns.set(rc={'figure.figsize':(8,10)})
sns.set_style('white')
abc= sns.barplot(x='host_name',y='total_price',data = top_3)
abc.set_title('Three hosts based on their turnover')
abc.set_ylabel('Host name')
abc.set_xlabel('Total price')
abc.set_xticklabels(abc.get_xticklabels(),rotation = 45,size='15')
# Out:
# [Text(0, 0, 'Sonder (NYC)'), Text(1, 0, 'Blueground'), Text(2, 0, 'Sally')]

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts provide a straightforward visual comparison of their turnover generated by three hosts. Each host can be represented by a separate bar and the length of the bar corresponds to their respective turnover. This allows for easy identification and comparison of turnover levels among the hosts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The host with the highest turnover will have the tallest bar, while the others will have shorter bars in descending order. This ranking provides a clear visual representation of host performance and helps identify the top-performing host in terms of turnover.According to the dataset provided Sonder(NYC) is the top performing host.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# They can be effectively used to communicate the insights about host turnover to various stakeholders, including management teams, investors or business partners.It allows a quick anf ituitive understanding of the turnover levels and differences among the hosts.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# visualization of total no. nights spend per location using seaborn
sns.set(rc={'figure.figsize':(10,5)})
sns.set_style('white')
abc= sns.barplot(x='neighbourhood_group',y='minimum_nights',data = final_nights)
abc.set_title('find total no. nights spend per location')
abc.set_ylabel('minimum night')
abc.set_xlabel('neighbourhood group')

abc.set_xticklabels(abc.get_xticklabels(),rotation = 45,size='15')
# Out:
# [Text(0, 0, 'Staten Island'),
#  Text(1, 0, 'Bronx'),
#  Text(2, 0, 'Queens'),
#  Text(3, 0, 'Brooklyn'),
#  Text(4, 0, 'Manhattan')]

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts allow easy visual comparison of the total number of nights per location across different neighbourhood groups. Each neighbourhood group can be represnted by a separate bar and the height of bar corresponds to the total number of nights.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The tallest bar represents the most popular locations in terms of Airbnb bookings, providing a clear visual indication of the areas where guests prefer to stay for longer durations. This information can be valuable for property owners,hosts, and investors seeking to focus their efforts and resources on high demand areas.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# They allow for easy comparison, identification of popular neighbourhoods, understanding the distribution of total nights, market segmentation, trend analysis, and provide an effective visualization format for interpreting communicating insights.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# create dataset
labels=list(room_types['room_type'])
sizes=list(room_types['minimum_nights'])
# create color parameter
colors=['green','pink','blue']
# create explode
explode = (0.07, 0.07, 0.07)
#creating pie chart
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True)
plt.title('Total no. of nights spend per room types', fontsize=20)
plt.axis("equal")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts provide a clear intuitive representation of the proportio of the total nights spent for each room type. Each room type is represented by a slice of the pie, and the size of each slice corresponds to the proportion of nights spent on that room type. This visual representation allows a quick understanding of the relative popularity and distribution of room types in terms of total nights.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Pie charts effectively highlight the dominant room types in terms of total nights spent. The larger slices or sections of the pie correspond to the room types that contribute significantly to the total nights and helps identify the roomtypes that are in high demand and preferred by guests.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# They allow the proportional representation comparison of room types, visualization of dominant room types, understanding overall distribution. They provide a visual snapshot of the distribution of nights spent across the different room types, helping stakeholders make informed decisions and understand guest preferences.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
correlation_matrix= df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix,annot= True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
# Out:
# <ipython-input-139-549f1bc830dc>:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Correlation maps helps in understanding the relationships between different variables or factors involved in Airbnb booking Analysis. By calculating correlation coefficients between pairs of variables, the maps provide a visual representation of the strength and direction of the relationships. This helps identify which variables are positively correlated(increase or decrease together) or negatively correlated(move in opposite directions)

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Correlation maps provide a visually intuitive representation of relationships among variables. They offer a concise and accessible way to communicate complex information to stakeholders, researchers or decision makers.In summary correlation maps are used n Airbnb analysis to understand relationships between variables, conduct multivariate analysis, facilitate hypothesis testing and provide visual representation for effective communication.They play a crucial role in uncovering insights, informing decision making, and exploring the complex dynamics of factors that influence Airbnb bookings.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(df)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pairplots allow for a visual exploration of relationships between multiple variables simultaneously.Each variable is plotted against every other variable in the dataset,creating a grid of scatter plots.This visualization helps identify potential patterns, trends and associations between variables in the context of Airbnb booking Analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# They help in understanding theinterplay between variables and provide a valuable tool for exploring and analying the complex dynamics of factors after affecting Airbnb Bookings.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Some potentail suggestions are:
# 1. Pricing Optimization: Identifying the patterns in pricing recommended adjuasting pricing strategies help clients maximize their revenue by setting competitive market appropriates.
# 2. Targetting high demand neighbourhood suggests focussing on these neighbourhood property acquisitions, investment or expansion helps clients capitalize property and demand in the area.
# 3. Enhancing the guest experience by addressing specific concerns or feedback related to cleanliness, checkin process and amenities.
# 4. Seasonal marketing strategies : This can help clients optimize their marketing efforts and increase bookings during high demand periods.
# 5. Long term versus short term rentals :Depending on the findings, suggest exploring options for property owners such as offering extended stays or adjusting rental periods to optimize revenue and occupancy rates.
# This will allow clients to adapt their strategies, pricing and offerings based on the evolving market dynamics.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# By Analyzing Airbnb New York(NYC) 2019 data we can uncover patterns, trends, and key factors influencing bookings.These insights can guide pricing strategies, property investments, marketing efforts and guest experience enhancements. It helps in strategic decision making for hosts, property owners and investors.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
